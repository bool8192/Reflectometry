# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import numpy as np
import torch
import torch.optim as optim
from variables import *
from ref import *
from read_complex_matrix import read_complex_matrix
from calculating_dynamic_resolution import *
torch.set_printoptions(precision=4)

matr = read_complex_matrix('ref_matrix.txt')
import timeit

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
data = np.loadtxt('experiment.txt')

r = data[:, 1]
r2 = data[:, 1] + data[:, 2]
r1 = data[:, 1] - data[:, 2]
sigma = sigma+0.0
Ibkg=Ibkg+0.0
I0_plus = np.mean(r[r > 0.9*r1[0]][0:1+math.ceil(len(r[r > 0.9*r1[0]])*0.7)])
I0 = torch.tensor(I0_plus).requires_grad_(True) - Ibkg

# %%
q = torch.pi*4.0e+10*torch.sin(torch.tensor(np.deg2rad(data[:, 0])))/1.524
r_mod, r_mod_conv= reflectometry(q, matr, sigma, sigma, I0, Ibkg)

fig, ax = plt.subplots(figsize=(18, 8))

ax.fill_between(q*1e-10, r1, r2, color='purple', alpha=0.7, label= 'эксперимент')
ax.plot(q.cpu().detach().numpy()[0:len(r_mod_conv.tolist())]*1e-10, (I0*r_mod_conv).tolist())
ax.set_yscale('log')

ax.legend()
plt.grid()
plt.show()

# %%
r = torch.tensor(data[:, 1], requires_grad = True)/I0

# %%
from objective_function import *

loss_function = Comparator(q, matr, 10*sigma, 6*sigma, I0, Ibkg)

objective_function = varbounds(all_bounds, loss_function.compare)
objective_function_weightless = varbounds(all_bounds, loss_function.compare_weightless)

# %%
initial_d = torch.tensor([700.0,  50.0, 20.0,  10.0, 100, 0], requires_grad=True)
initial_r_rho = torch.tensor([88.575,  7.5, 8.575], requires_grad=True)
initial_i_rho = torch.tensor([-7.648, 0, -10.111], requires_grad=True)

initial_sigma = torch.tensor(0.01, requires_grad=True)

I_bounds =  torch.tensor([0.997*I0 , 1.003*I0]).requires_grad_(True)
Ibkg_bounds = torch.tensor([0.0, 3*Ibkg]).requires_grad_(True)

r_rho_bounds = torch.tensor([[80.0, 97.0], [-10.0, 20.0], [4.0, 14.0]], requires_grad=True)
i_rho_bounds = torch.tensor([[-70.0, -7.0], [-20.0, 0.0], [-20.0, -0.1]], requires_grad=True)

initial_sigma1 = torch.nn.Parameter(torch.tensor(0.01, dtype=torch.float64))
initial_sigma2 = torch.nn.Parameter(torch.tensor(0.01, dtype=torch.float64))
sigma_bounds1 =  torch.tensor([0.001 , 0.02]).requires_grad_(False)
sigma_bounds2 =  torch.tensor([0.001 , 0.02]).requires_grad_(False)

# %%
objective_function_weightless.objective_function(initial_d, torch.complex(initial_r_rho, initial_i_rho), sigma1, sigma2, I0, Ibkg)
# Out:
# tensor(5.9952, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
objective_function.objective_function(initial_d, torch.complex(initial_r_rho, initial_i_rho), sigma1, sigma2, I0, Ibkg)
# Out:
# tensor(0.0030, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
from optimizer import *
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses1 = adamw(q, r, objective_function.objective_function, initial_sigma1, initial_sigma2,
                                                                      initial_d, initial_r_rho, initial_i_rho, I0, Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.002, max_iter = 120, k=3)
# Out:
# relative_loss:   1.0
#  d:   tensor([6.9801e+02, 5.1998e+01, 1.8000e+01, 1.0000e+01, 1.0000e+02, 1.0000e-03])     grad_d:   tensor([ 2.1516e-06, -9.7905e-06,  3.1288e-04, -1.2334e-04,  0.0000e+00,
#         -2.1286e-03])
#  rho:   tensor([88.5730-7.6478j,  7.4980+0.0000j,  8.5730-10.1130j])     grad_rho:   tensor([7.8085e-03+1.5115e-02j, 3.2696e-03+5.9839e-03j, 1.5540e-05+1.1952e-05j])
#  I:   tensor(7968662.9478, dtype=torch.float64)     grad_I:   tensor(4.0739e-17, dtype=torch.float64)
#  Ibkg:   tensor(1.1011, dtype=torch.float64)     grad_Ibkg:   tensor(-2.9512e-10, dtype=torch.float64)
#  learning_rate:   2.0
#  iteration:   1
# relative_loss:   0.7497157747043501
#  d:   tensor([738.0752, 143.2481,   8.6692,   4.9441, 100.0000,   0.0000])     grad_d:   tensor([-5.1843e-07, -2.7297e-06,  1.0109e-06,  9.6871e-07,  0.0000e+00,
#          4.8210e-05])
#  rho:   tensor([88.4702-7.6390j,  7.4824+0.0000j,  8.5301-10.0420j])     grad_rho:   tensor([ 3.8200e-03+7.0981e-03j,  2.8472e-05+4.9603e-05j,
#         -1.4029e-07-3.5751e-06j])
#  I:   tensor(7992650.6583, dtype=torch.float64)     grad_I:   tensor(-0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(1.5660e-08, dtype=torch.float64)
#  learning_rate:   1.8823839999999998
#  iteration:   60
# relative_loss:   0.7475674555398643
#  d:   tensor([772.1446, 168.3856,   6.4915,   0.0000, 100.0000,   0.0000])     grad_d:   tensor([-6.2864e-09, -5.3519e-07, -6.3283e-08,  2.6717e-08,  0.0000e+00,
#          2.5540e-04])
#  rho:   tensor([88.3751-7.6307j,  7.4923+0.0000j,  8.5353-10.0183j])     grad_rho:   tensor([ 2.7641e-03+6.0394e-03j, -1.0054e-04-1.9683e-04j,
#          7.4129e-07-2.8235e-07j])
#  I:   tensor(7992650.6583, dtype=torch.float64)     grad_I:   tensor(-0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(9.5792e-09, dtype=torch.float64)
#  learning_rate:   1.8078415935999996
#  iteration:   119

# %%
objective_function_sigma = varsigma(ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss_function.compare, all_bounds)

from scipy.optimize import differential_evolution as de

bounds = [sigma_bounds1,
          sigma_bounds2]

ans_sigma1, ans_sigma2 = de(
    func=objective_function_sigma.objective_function,
    bounds=bounds
).x

# %%
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses2 = adamw(q, r, objective_function_weightless.objective_function, 
                                                                      ans_sigma1, ans_sigma2, 
                                                                      ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.001, max_iter = 260, k=3)
# Out:
# relative_loss:   1.0
#  d:   tensor([7.7318e+02, 1.6760e+02, 7.4951e+00, 0.0000e+00, 1.0000e+02, 1.0000e-03])     grad_d:   tensor([-2.0706e-02,  2.7659e-03, -9.0319e+00,  4.2253e+00,  0.0000e+00,
#         -1.0968e+01])
#  rho:   tensor([88.3727-7.6305j,  7.4922+0.0000j,  8.5340-10.0172j])     grad_rho:   tensor([2.7967-0.6825j, 1.1258+6.5201j, 0.2230-0.2664j])
#  I:   tensor(7992650.6583, dtype=torch.float64)     grad_I:   tensor(-0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(0.1105, dtype=torch.float64)
#  learning_rate:   1.0
#  iteration:   1
# relative_loss:   0.025769929605084757
#  d:   tensor([772.3692, 168.0394,  17.6104,   8.1817, 100.0000,   0.0000])     grad_d:   tensor([-9.3420e-07, -6.1154e-07,  1.6971e-04,  8.6258e-05,  0.0000e+00,
#          1.3143e-01])
#  rho:   tensor([88.3487-7.6285j,  7.5334+0.0000j,  8.4458-9.9302j])     grad_rho:   tensor([-0.0310+0.1141j, -0.0874-0.1058j,  0.0490-0.0555j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(1.3606e-11, dtype=torch.float64)
#  Ibkg:   tensor(0.0851, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0013, dtype=torch.float64)
#  learning_rate:   0.8858423808639998
#  iteration:   130
# relative_loss:   0.025198217250399873
#  d:   tensor([772.4640, 168.4258,  17.5607,   8.1331, 100.0000,   0.0000])     grad_d:   tensor([-4.2913e-05,  1.1701e-06,  2.6845e-03, -3.3004e-03,  0.0000e+00,
#          1.2803e-01])
#  rho:   tensor([88.3680-7.6301j,  7.5823+0.0000j,  8.3458-9.8305j])     grad_rho:   tensor([-0.0287+0.1131j, -0.0851-0.1031j,  0.0484-0.0550j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(6.3549e-11, dtype=torch.float64)
#  Ibkg:   tensor(0.4370, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0012, dtype=torch.float64)
#  learning_rate:   0.7847167237347998
#  iteration:   259

# %%
objective_function_weightless_sigma = varsigma(ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss_function.compare_weightless, all_bounds)
ans_sigma1, ans_sigma2 = de(
    func=objective_function_weightless_sigma.objective_function,
    bounds=bounds,
).x

ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses3 = adamw(q, r, objective_function_weightless.objective_function, 
                                                                      ans_sigma1, ans_sigma2, 
                                                                      ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.0002, max_iter = 800, k=10)
# Out:
# relative_loss:   1.0
#  d:   tensor([772.2609, 168.2318,  17.3624,   8.3290, 100.0000,   0.0000])     grad_d:   tensor([ 2.1275e-05,  1.0398e-05,  9.3333e-03, -1.4033e-02,  0.0000e+00,
#          1.3593e-01])
#  rho:   tensor([88.3685-7.6302j,  7.5830+0.0000j,  8.3448-9.8296j])     grad_rho:   tensor([-0.0259+0.1141j, -0.0883-0.1042j,  0.0493-0.0558j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(5.1746e-11, dtype=torch.float64)
#  Ibkg:   tensor(0.4452, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0009, dtype=torch.float64)
#  learning_rate:   0.2
#  iteration:   1
# relative_loss:   0.9926839720006508
#  d:   tensor([772.4233, 168.2400,  17.5580,   8.1364, 100.0000,   0.0000])     grad_d:   tensor([-9.4080e-07, -5.9987e-08,  8.9624e-06,  8.3284e-06,  0.0000e+00,
#          1.1958e-01])
#  rho:   tensor([88.3832-7.6314j,  7.5982+0.0000j,  8.3279-9.8126j])     grad_rho:   tensor([-0.0270+0.1143j, -0.0808-0.0987j,  0.0488-0.0553j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(9.5320e-11, dtype=torch.float64)
#  Ibkg:   tensor(0.6421, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0012, dtype=torch.float64)
#  learning_rate:   0.184473632
#  iteration:   89
# relative_loss:   0.9856945859008387
#  d:   tensor([772.4540, 168.2885,  17.5515,   8.1362, 100.0000,   0.0000])     grad_d:   tensor([-3.5511e-05,  9.3364e-07,  2.0835e-03, -2.6340e-03,  0.0000e+00,
#          1.1978e-01])
#  rho:   tensor([88.3979-7.6327j,  7.6133+0.0000j,  8.3123-9.7971j])     grad_rho:   tensor([-0.0247+0.1148j, -0.0801-0.0973j,  0.0487-0.0553j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(1.2515e-10, dtype=torch.float64)
#  Ibkg:   tensor(0.8944, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0011, dtype=torch.float64)
#  learning_rate:   0.1701526045163571
#  iteration:   177
# relative_loss:   0.9793961593998711
#  d:   tensor([772.4795, 168.3349,  17.5482,   8.1334, 100.0000,   0.0000])     grad_d:   tensor([-3.5395e-05,  9.0875e-07,  2.0853e-03, -2.6188e-03,  0.0000e+00,
#          1.1749e-01])
#  rho:   tensor([88.4113-7.6339j,  7.6271+0.0000j,  8.2981-9.7829j])     grad_rho:   tensor([-0.0230+0.1152j, -0.0785-0.0953j,  0.0486-0.0551j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(1.5595e-10, dtype=torch.float64)
#  Ibkg:   tensor(1.1301, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0011, dtype=torch.float64)
#  learning_rate:   0.15380447785202078
#  iteration:   265
# relative_loss:   0.9806731681493015
#  d:   tensor([772.5323, 168.3425,  17.5148,   8.1585, 100.0000,   0.0000])     grad_d:   tensor([-1.6076e-03,  4.6301e-05,  9.7255e-02, -1.2293e-01,  0.0000e+00,
#          2.3775e-01])
#  rho:   tensor([88.4236-7.6349j,  7.6398+0.0000j,  8.2851-9.7698j])     grad_rho:   tensor([-0.0041+0.1189j, -0.1226-0.1364j,  0.0502-0.0576j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(-2.1243e-10, dtype=torch.float64)
#  Ibkg:   tensor(1.3536, dtype=torch.float64)     grad_Ibkg:   tensor(0.0012, dtype=torch.float64)
#  learning_rate:   0.14186435323612914
#  iteration:   353
# relative_loss:   0.9685045926059697
#  d:   tensor([772.5297, 168.4117,  17.5378,   8.1332, 100.0000,   0.0000])     grad_d:   tensor([-7.9444e-05,  2.2895e-06,  4.7885e-03, -6.0554e-03,  0.0000e+00,
#          1.1698e-01])
#  rho:   tensor([88.4348-7.6359j,  7.6514+0.0000j,  8.2732-9.7579j])     grad_rho:   tensor([-0.0195+0.1159j, -0.0770-0.0928j,  0.0484-0.0550j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(1.9667e-10, dtype=torch.float64)
#  Ibkg:   tensor(1.5610, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0010, dtype=torch.float64)
#  learning_rate:   0.1282341392147185
#  iteration:   441
# relative_loss:   0.9643194149571235
#  d:   tensor([772.5500, 168.4425,  17.5345,   8.1306, 100.0000,   0.0000])     grad_d:   tensor([ 4.3949e-04, -1.2845e-05, -2.6929e-02,  3.3862e-02,  0.0000e+00,
#          7.4198e-02])
#  rho:   tensor([88.4451-7.6368j,  7.6621+0.0000j,  8.2623-9.7471j])     grad_rho:   tensor([-0.0237+0.1151j, -0.0606-0.0766j,  0.0478-0.0541j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(3.8976e-10, dtype=torch.float64)
#  Ibkg:   tensor(1.7552, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0018, dtype=torch.float64)
#  learning_rate:   0.11827908703666373
#  iteration:   529
# relative_loss:   0.9598292535732733
#  d:   tensor([772.5639, 168.4812,  17.5374,   8.1254, 100.0000,   0.0000])     grad_d:   tensor([ 3.3673e-04, -9.9700e-06, -2.0589e-02,  2.6122e-02,  0.0000e+00,
#          8.0695e-02])
#  rho:   tensor([88.4545-7.6376j,  7.6719+0.0000j,  8.2524-9.7371j])     grad_rho:   tensor([-0.0216+0.1156j, -0.0624-0.0782j,  0.0478-0.0542j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(3.9029e-10, dtype=torch.float64)
#  Ibkg:   tensor(1.9354, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0016, dtype=torch.float64)
#  learning_rate:   0.10909686387648737
#  iteration:   617
# relative_loss:   0.9556354027494689
#  d:   tensor([772.5842, 168.5083,  17.5320,   8.1267, 100.0000,   0.0000])     grad_d:   tensor([-4.3814e-06,  1.5165e-07,  2.3083e-04, -2.8130e-04,  0.0000e+00,
#          1.0623e-01])
#  rho:   tensor([88.4631-7.6383j,  7.6809+0.0000j,  8.2433-9.7280j])     grad_rho:   tensor([-0.0167+0.1166j, -0.0714-0.0863j,  0.0481-0.0546j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(2.8515e-10, dtype=torch.float64)
#  Ibkg:   tensor(2.1016, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0011, dtype=torch.float64)
#  learning_rate:   0.0986149241236156
#  iteration:   705
# relative_loss:   0.952120026986136
#  d:   tensor([772.6011, 168.5331,  17.5290,   8.1264, 100.0000,   0.0000])     grad_d:   tensor([-4.7366e-05,  1.3509e-06,  2.8998e-03, -3.6610e-03,  0.0000e+00,
#          1.0833e-01])
#  rho:   tensor([88.4711-7.6390j,  7.6891+0.0000j,  8.2349-9.7197j])     grad_rho:   tensor([-0.0152+0.1169j, -0.0718-0.0862j,  0.0481-0.0546j])
#  I:   tensor(7944838.1917, dtype=torch.float64)     grad_I:   tensor(2.8454e-10, dtype=torch.float64)
#  Ibkg:   tensor(2.2550, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0010, dtype=torch.float64)
#  learning_rate:   0.09095926611243892
#  iteration:   793

# %%
rel_losses2 = list(map(lambda x: x * rel_losses1[-1],  rel_losses2))
rel_losses3 = list(map(lambda x: x * rel_losses2[-1],  rel_losses3))
rel_losses = rel_losses1 + rel_losses2 + rel_losses3

# %%
fig, ax = plt.subplots(figsize =(15, 4))

ax.plot(range(0,len(rel_losses)), rel_losses, label='AdamW')

ax.set_yscale('log')
ax.legend()
plt.grid()
plt.show()

# %%
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss
# Out:
# (tensor([772.6013, 168.5362,  17.5297,   8.1253, 100.0000,   0.0000]),
#  tensor([88.4716,  7.6897,  8.2343]),
#  tensor([-7.6391,  0.0000, -9.7190]),
#  tensor(7944838.1917, dtype=torch.float64),
#  tensor(2.2668, dtype=torch.float64),
#  0.7422988843316676)

# %%
ans_sigma1, ans_sigma2
# Out:
# (np.float64(0.019352576877770505), np.float64(0.019737566877229093))

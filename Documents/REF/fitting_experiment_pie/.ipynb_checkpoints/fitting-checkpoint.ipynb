# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import numpy as np
import torch
import torch.optim as optim
from variables import *
from ref import *
from read_complex_matrix import read_complex_matrix
from calculating_dynamic_resolution import *
torch.set_printoptions(precision=4)

import timeit

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
matr
# Out:
# tensor([[ 10.0000+0.0000j,   0.0000+0.0000j,   0.0000+0.0000j],
#         [700.0000+0.0000j,  88.5750-7.6480j, 100.0000+0.0000j],
#         [ 20.0000+0.0000j,   7.5000-0.0000j,   5.0000+0.0000j],
#         [100.0000+0.0000j,   8.5750-0.1110j,  10.0000+0.0000j]],
#        requires_grad=True)

# %%
q = torch.pi*4.0e+10*torch.sin(torch.tensor(np.deg2rad(data[:, 0])))/1.524
r_mod, r_mod_conv= reflectometry(q, matr, sigma, sigma, I0, Ibkg)

fig, ax = plt.subplots(figsize=(18, 8))

ax.fill_between(q*1e-10, r1, r2, color='purple', alpha=0.7, label= 'эксперимент')
ax.plot(q.cpu().detach().numpy()[0:len(r_mod_conv.tolist())]*1e-10, (I0*r_mod_conv).tolist())
ax.set_yscale('log')

ax.legend()
plt.grid()
plt.show()

r = torch.tensor(r/I0.cpu().detach().numpy())

# %%
from objective_function import *

loss_function = Comparator(q, r)

objective_function = varbounds(all_bounds, loss_function.compare)
objective_function_weightless = varbounds(all_bounds, loss_function.compare_weightless)

# %%
objective_function_weightless.objective_function(initial_d, torch.complex(initial_r_rho, initial_i_rho), sigma1, sigma2, I0, Ibkg)
# Out:
# tensor(294080.8763, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
objective_function.objective_function(initial_d, torch.complex(initial_r_rho, initial_i_rho), sigma1, sigma2, I0, Ibkg)
# Out:
# tensor(2.2384, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
from optimizer import *
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses1 = adamw(q, r, objective_function.objective_function, initial_sigma1, initial_sigma2,
                                                                      initial_d, initial_r_rho, initial_i_rho, I0, Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.11, max_iter = 150, k=8)
# Out:
# relative_loss:   1.0
#  d:   tensor([702.1880, 102.1984,  17.8000,   7.2000, 100.0000,   7.8000])     grad_d:   tensor([-1.8295e-06, -1.3877e-05,  9.7828e-03, -3.0428e-03,  0.0000e+00,
#          1.1328e-02])
#  rho:   tensor([89.6750-7.7430j,  8.6000-0.0000j,  7.4750-0.2109j])     grad_rho:   tensor([-0.3391-0.4381j, -0.2077-0.4065j,  0.0054-0.0989j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.1935e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.2904, dtype=torch.float64)     grad_Ibkg:   tensor(-2.2722e-06, dtype=torch.float64)
#  learning_rate:   2.2
#  iteration:   1
# relative_loss:   0.41678114400876975
#  d:   tensor([747.4114, 142.5178,  32.2491,   0.0000, 100.0000,   6.1121])     grad_d:   tensor([-6.2077e-07,  4.3302e-07,  8.1492e-03, -3.8214e-03,  0.0000e+00,
#          6.9615e-03])
#  rho:   tensor([97.1500-8.3884j, 30.2746-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.1535-0.2232j, -0.2204-0.4224j,  0.0010-0.0463j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(6.0227e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-1.4241e-06, dtype=torch.float64)
#  learning_rate:   2.156
#  iteration:   22
# relative_loss:   0.23789801042797312
#  d:   tensor([782.6196, 165.1613,  31.7512,   0.0000, 100.0000,   0.0000])     grad_d:   tensor([ 2.0129e-07, -3.1182e-07, -6.7885e-03,  3.1832e-03,  0.0000e+00,
#         -2.5505e-03])
#  rho:   tensor([97.1500-8.3884j, 52.0332-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-8.1997e-02-1.2508e-01j, -1.2579e-01-2.3657e-01j,
#          5.8607e-08-1.0035e-06j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(4.6106e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-1.0902e-06, dtype=torch.float64)
#  learning_rate:   2.11288
#  iteration:   43
# relative_loss:   0.10324026120783042
#  d:   tensor([8.0019e+02, 1.8192e+02, 4.0000e+01, 0.0000e+00, 1.0000e+02, 4.9481e-01])     grad_d:   tensor([ 1.4373e-06, -7.1708e-07, -7.8737e-03,  3.6926e-03,  0.0000e+00,
#         -3.5758e-03])
#  rho:   tensor([97.1500-8.3884j, 72.9893-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-8.3842e-03-0.0323j, -5.3553e-02-0.1034j, -2.0257e-05-0.0008j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(2.0087e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-4.7497e-07, dtype=torch.float64)
#  learning_rate:   2.0706224
#  iteration:   64
# relative_loss:   0.21003658358016486
#  d:   tensor([793.4561, 197.5262,  40.0000,   0.0000, 100.0000,  11.4024])     grad_d:   tensor([ 1.9431e-06, -1.1391e-06,  8.5276e-04, -3.9894e-04,  0.0000e+00,
#         -2.0607e-03])
#  rho:   tensor([97.1500-8.3884j, 90.6945-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([ 0.0418-0.0047j,  0.0655+0.0887j, -0.0005+0.0092j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(-3.0577e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(7.2736e-07, dtype=torch.float64)
#  learning_rate:   2.029209952
#  iteration:   85
# relative_loss:   0.3933311527531242
#  d:   tensor([7.7277e+02, 2.1389e+02, 3.9644e+01, 2.4512e-01, 1.0000e+02, 2.6143e+01])     grad_d:   tensor([ 6.9476e-07, -9.7185e-07,  1.5848e-02, -7.4332e-03,  0.0000e+00,
#         -1.3122e-03])
#  rho:   tensor([97.1500-8.3884j, 97.1500-0.0000j,  9.2000-0.2109j])     grad_rho:   tensor([ 0.0485-0.0122j,  0.1431+0.2031j, -0.0024+0.0704j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(-5.3335e-13, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(1.2687e-06, dtype=torch.float64)
#  learning_rate:   1.98862575296
#  iteration:   106
# relative_loss:   0.24952871986639397
#  d:   tensor([753.3701, 230.2173,  26.8818,  12.3956, 100.0000,  42.4173])     grad_d:   tensor([-1.2390e-06, -3.3605e-07,  1.2205e-02, -5.8815e-03,  0.0000e+00,
#         -3.6328e-03])
#  rho:   tensor([97.1500-8.3884j, 96.6341-0.0000j,  9.2000-0.2109j])     grad_rho:   tensor([ 0.0438-0.0068j,  0.0706+0.0960j, -0.0059+0.0325j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(-1.1485e-13, dtype=torch.float64)
#  Ibkg:   tensor(0.9465, dtype=torch.float64)     grad_Ibkg:   tensor(7.2586e-07, dtype=torch.float64)
#  learning_rate:   1.9488532379008
#  iteration:   127
# relative_loss:   0.13729685783263157
#  d:   tensor([747.1054, 244.5630,   7.4494,  20.0000, 100.0000,  65.3384])     grad_d:   tensor([-9.7521e-07, -5.8016e-08, -6.3172e-03,  3.1469e-03,  0.0000e+00,
#         -5.5700e-03])
#  rho:   tensor([97.1500-8.3884j, 94.2955-0.0000j,  9.2000-0.2109j])     grad_rho:   tensor([ 0.0007-0.0339j, -0.0251-0.0538j, -0.0070-0.1637j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(-2.4418e-07, dtype=torch.float64)
#  learning_rate:   1.9098761731427838
#  iteration:   148

# %%
objective_function_sigma = varsigma(ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss_function.compare, all_bounds)

from scipy.optimize import differential_evolution as de

bounds = [sigma_bounds1,
          sigma_bounds2]

ans_sigma1, ans_sigma2 = de(
    func=objective_function_sigma.objective_function,
    bounds=bounds
).x

# %%
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses2 = adamw(q, r, objective_function_weightless.objective_function, 
                                                                      ans_sigma1, ans_sigma2, 
                                                                      ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.006, max_iter = 660, k=5)
# Out:
# relative_loss:   1.0
#  d:   tensor([746.9372, 245.6753,   5.8149,  20.0000, 100.0000,  67.7613])     grad_d:   tensor([  0.0869,   0.0960,  20.5438, -16.6099,   0.0000,   2.3989])
#  rho:   tensor([97.0900-8.3832j, 94.0568-0.0000j,  9.1400-0.2109j])     grad_rho:   tensor([ 3.1834-15.1862j,  1.1140+23.8446j, 49.8019+7.4336j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(-0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(1.8408, dtype=torch.float64)
#  learning_rate:   0.12
#  iteration:   1
# relative_loss:   0.31665858458647156
#  d:   tensor([7.5369e+02, 2.2930e+02, 3.9836e-01, 2.0000e+01, 1.0000e+02, 6.3309e+01])     grad_d:   tensor([ 0.0453, -0.0197, -0.4533, -1.3308,  0.0000,  1.6792])
#  rho:   tensor([97.1500-8.3884j, 87.3172-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.3565-4.4050j,  2.1812+6.3868j,  4.3803-4.4484j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(0., dtype=torch.float64)
#  Ibkg:   tensor(0., dtype=torch.float64)     grad_Ibkg:   tensor(-0.0896, dtype=torch.float64)
#  learning_rate:   0.10209156270981425
#  iteration:   165
# relative_loss:   0.32719399853228986
#  d:   tensor([755.7769, 231.0322,   1.3968,  20.0000, 100.0000,  58.8313])     grad_d:   tensor([-2.2936e-02, -5.6815e-03, -5.9390e+00,  1.3772e+00,  0.0000e+00,
#         -1.7061e+00])
#  rho:   tensor([97.1500-8.3884j, 82.4211-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-1.1965-5.1096j,  3.5807+7.4430j,  3.2728-5.6619j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(5.9825e-08, dtype=torch.float64)
#  Ibkg:   tensor(1.9892, dtype=torch.float64)     grad_Ibkg:   tensor(-0.2382, dtype=torch.float64)
#  learning_rate:   0.08685572647109947
#  iteration:   329
# relative_loss:   0.28294210696472033
#  d:   tensor([757.3374, 232.9458,   3.8818,  20.0000, 100.0000,  53.6649])     grad_d:   tensor([-0.0204,  0.0092, -2.2217, -0.0709,  0.0000,  0.4978])
#  rho:   tensor([97.0885-8.3831j, 78.1648-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0951-2.8033j,  2.0008+4.6053j,  0.3223-5.2938j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(1.3634e-07, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.3224, dtype=torch.float64)
#  learning_rate:   0.07389364038108939
#  iteration:   493
# relative_loss:   0.24974242099553662
#  d:   tensor([758.4174, 231.2059,   5.8728,  20.0000, 100.0000,  49.3975])     grad_d:   tensor([-0.0061, -0.0019,  0.8784, -0.8256,  0.0000,  0.9127])
#  rho:   tensor([96.6980-8.3494j, 74.7293-0.0000j,  7.1163-0.2109j])     grad_rho:   tensor([ 0.2356-0.9926j,  0.9398+1.8434j, -2.0428-3.1927j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(2.0554e-07, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.4860, dtype=torch.float64)
#  learning_rate:   0.06286597684018709
#  iteration:   657

# %%
objective_function_weightless_sigma = varsigma(ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss_function.compare_weightless, all_bounds)
ans_sigma1, ans_sigma2 = de(
    func=objective_function_weightless_sigma.objective_function,
    bounds=bounds,
).x

ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss, rel_losses3 = adamw(q, r, objective_function_weightless.objective_function, 
                                                                      ans_sigma1, ans_sigma2, 
                                                                      ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, 
                                                                      d_bounds, r_rho_bounds, i_rho_bounds, I_bounds, Ibkg_bounds,
                                                                      lr= 0.003, max_iter = 2900, k=12)
# Out:
# relative_loss:   1.0
#  d:   tensor([758.4938, 231.2524,   5.8380,  20.0000, 100.0000,  49.2835])     grad_d:   tensor([-0.0313, -0.0037,  0.2807, -0.4894,  0.0000,  0.4738])
#  rho:   tensor([96.7207-8.3513j, 74.6445-0.0000j,  7.1601-0.2109j])     grad_rho:   tensor([-0.0027-1.3376j,  1.0120+1.8653j, -2.5353-2.9531j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(2.0773e-07, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.4912, dtype=torch.float64)
#  learning_rate:   0.06
#  iteration:   1
# relative_loss:   0.5277205444684162
#  d:   tensor([762.7928, 231.4937,   7.2428,  14.9922, 100.0000,  40.8679])     grad_d:   tensor([ 0.0168,  0.0043, -0.7552, -0.5434,  0.0000,  0.9829])
#  rho:   tensor([96.8721-8.3644j, 67.8672-0.0000j,  9.2000-0.2109j])     grad_rho:   tensor([1.3125+0.4364j, 0.3043+2.0993j, 1.0095-1.8086j])
#  I:   tensor(7849893.1918, dtype=torch.float64)     grad_I:   tensor(-4.7172e-09, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(0.0112, dtype=torch.float64)
#  learning_rate:   0.046141343355606226
#  iteration:   264
# relative_loss:   0.4594790967372709
#  d:   tensor([762.5475, 225.9781,   7.7915,  15.2322, 100.0000,  38.5239])     grad_d:   tensor([ 0.0167, -0.0015,  0.1772,  0.2674,  0.0000, -0.1452])
#  rho:   tensor([92.4516-7.9827j, 64.2138-0.0000j,  8.4362-0.2109j])     grad_rho:   tensor([0.0107+1.0689j, 0.4427-0.1537j, 0.1201-1.7395j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(7.8183e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.1849, dtype=torch.float64)
#  learning_rate:   0.03548372611099912
#  iteration:   527
# relative_loss:   0.4625772672182078
#  d:   tensor([760.3342, 231.3680,   7.0609,  14.8404, 100.0000,  39.4593])     grad_d:   tensor([ 0.0009,  0.0028, -0.0230, -0.0618,  0.0000,  0.0815])
#  rho:   tensor([90.6253-7.8250j, 62.3029-0.0000j,  7.2210-0.2109j])     grad_rho:   tensor([0.0523+0.6971j, 0.1606+0.1374j, 0.1589-2.1335j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.1248e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0739, dtype=torch.float64)
#  learning_rate:   0.02728777983373168
#  iteration:   790
# relative_loss:   0.46091122016909886
#  d:   tensor([759.6594, 230.2544,   7.8399,  16.3413, 100.0000,  39.0488])     grad_d:   tensor([ 1.9505e-03,  2.7896e-06, -5.3797e-03, -3.6961e-02,  0.0000e+00,
#          2.3847e-02])
#  rho:   tensor([90.1444-7.7835j, 61.0428-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0105+0.7140j,  0.1053-0.0079j,  0.2199-2.0310j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.1063e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0734, dtype=torch.float64)
#  learning_rate:   0.020984913645340015
#  iteration:   1053
# relative_loss:   0.4556929302800638
#  d:   tensor([759.3610, 230.0650,   8.4867,  17.4592, 100.0000,  38.6709])     grad_d:   tensor([ 4.6944e-04,  1.5798e-05, -9.3508e-03, -2.4000e-02,  0.0000e+00,
#          4.7068e-03])
#  rho:   tensor([90.1254-7.7819j, 60.3598-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0078+0.7601j,  0.0498-0.0952j,  0.3827-1.8603j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.1512e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0745, dtype=torch.float64)
#  learning_rate:   0.016137868429956334
#  iteration:   1316
# relative_loss:   0.45158750327049074
#  d:   tensor([759.2016, 229.9747,   8.8469,  18.1125, 100.0000,  38.5128])     grad_d:   tensor([-6.0774e-05,  3.1711e-05, -8.1641e-03, -1.6895e-02,  0.0000e+00,
#          5.2153e-03])
#  rho:   tensor([90.1847-7.7870j, 60.0125-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0056+0.7790j,  0.0261-0.1329j,  0.4659-1.7920j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.1833e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0753, dtype=torch.float64)
#  learning_rate:   0.012410382137570222
#  iteration:   1579
# relative_loss:   0.4485092107304441
#  d:   tensor([759.1163, 229.8980,   9.0709,  18.5221, 100.0000,  38.4234])     grad_d:   tensor([ 8.2374e-05,  7.8212e-06, -5.0553e-03, -1.0061e-02,  0.0000e+00,
#          2.7546e-03])
#  rho:   tensor([90.2490-7.7925j, 59.8124-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0059+0.7871j,  0.0184-0.1515j,  0.5005-1.7569j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.2204e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0761, dtype=torch.float64)
#  learning_rate:   0.009352984488603864
#  iteration:   1842
# relative_loss:   0.446197701744075
#  d:   tensor([759.0574, 229.8629,   9.2226,  18.8006, 100.0000,  38.3668])     grad_d:   tensor([ 4.0320e-05,  1.2230e-05, -3.9368e-03, -7.1942e-03,  0.0000e+00,
#          1.6746e-03])
#  rho:   tensor([90.3036-7.7973j, 59.6807-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0045+0.7909j,  0.0131-0.1610j,  0.5230-1.7324j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.2312e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0764, dtype=torch.float64)
#  learning_rate:   0.007192654478138832
#  iteration:   2105
# relative_loss:   0.44447463084199573
#  d:   tensor([759.0168, 229.8343,   9.3310,  19.0005, 100.0000,  38.3281])     grad_d:   tensor([ 6.4934e-05,  7.4406e-06, -2.6488e-03, -5.4506e-03,  0.0000e+00,
#          1.3545e-03])
#  rho:   tensor([90.3462-7.8009j, 59.5876-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0034+0.7933j,  0.0096-0.1672j,  0.5384-1.7154j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.2379e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0766, dtype=torch.float64)
#  learning_rate:   0.005531312331900711
#  iteration:   2368
# relative_loss:   0.44319722716881543
#  d:   tensor([758.9872, 229.8149,   9.4103,  19.1465, 100.0000,  38.3001])     grad_d:   tensor([ 7.3466e-05,  6.3712e-06, -1.8661e-03, -4.1739e-03,  0.0000e+00,
#          1.0937e-03])
#  rho:   tensor([90.3784-7.8037j, 59.5194-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0025+0.7949j,  0.0071-0.1715j,  0.5496-1.7030j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.2423e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0767, dtype=torch.float64)
#  learning_rate:   0.004253703025222161
#  iteration:   2631
# relative_loss:   0.4422521770009478
#  d:   tensor([758.9655, 229.7992,   9.4690,  19.2545, 100.0000,  38.2791])     grad_d:   tensor([ 4.3955e-05,  3.9210e-06, -9.9597e-04, -3.2212e-03,  0.0000e+00,
#          8.9648e-04])
#  rho:   tensor([90.4024-7.8058j, 59.4686-0.0000j,  7.0000-0.2109j])     grad_rho:   tensor([-0.0018+0.7961j,  0.0053-0.1748j,  0.5576-1.6939j])
#  I:   tensor(7802934.7082, dtype=torch.float64)     grad_I:   tensor(3.2463e-08, dtype=torch.float64)
#  Ibkg:   tensor(3.3000, dtype=torch.float64)     grad_Ibkg:   tensor(-0.0768, dtype=torch.float64)
#  learning_rate:   0.0032711928636592774
#  iteration:   2894

# %%
rel_losses2 = list(map(lambda x: x * rel_losses1[-1],  rel_losses2))
rel_losses3 = list(map(lambda x: x * rel_losses2[-1],  rel_losses3))
rel_losses = rel_losses1 + rel_losses2 + rel_losses3

# %%
fig, ax = plt.subplots(figsize =(15, 4))

ax.plot(range(0,len(rel_losses)), rel_losses, label='AdamW')

ax.set_yscale('log')
ax.legend()
plt.grid()
plt.show()

# %%
ans_d, ans_r_rho, ans_i_rho, ans_I, ans_Ibkg, loss
# Out:
# (tensor([758.9651, 229.7990,   9.4701,  19.2566, 100.0000,  38.2787]),
#  tensor([90.4029, 59.4676,  7.0000]),
#  tensor([-7.8058, -0.0000, -0.2109]),
#  tensor(7802934.7082, dtype=torch.float64),
#  tensor(3.3000, dtype=torch.float64),
#  14.411975782464054)

# %%
ans_sigma1, ans_sigma2
# Out:
# (np.float64(0.002153610346563673), np.float64(0.01092042829476487))

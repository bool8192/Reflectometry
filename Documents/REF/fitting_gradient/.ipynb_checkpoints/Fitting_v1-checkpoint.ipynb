# %%
from ref import *
from read_complex_matrix import read_complex_matrix
matr = read_complex_matrix('ref_matrix.txt')
import timeit

# %%
# %%time

x_crit, x_max, y_max, x_min, y_min = reflectometry_trace(matr[1,2], matr[1,0], matr[2,2], matr[2,0])
# Out:
# CPU times: total: 15.6 ms
# Wall time: 3 ms

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

#ax.plot(q[0:len(y)]*1e-9, y)
ax.scatter(x_max*1e-9, y_max, color = 'orange')
ax.scatter(x_min*1e-9, y_min, color = 'cyan')
ax.scatter(x_crit*1e-9, 0.9, color = 'red')

ax.set_yscale('log')

plt.show()

# %%
def loss_function(crit1, r_max1, q_max1, r_min1, q_min1, crit2, r_max2, q_max2, r_min2, q_min2):
    #r_min могут плохо сходиться в случаях со свёрткой, т.к. она их завышает на порядок
    return (2*(crit1-crit2)/crit1)**2 + np.sum(((r_max1-r_max2)/r_max1)**2) + np.sum(((q_max1-q_max2)/q_max1)**2) + np.sum(((q_min1-q_min2)/q_min1)**2)

# %%
original_trace = reflectometry_trace(matr[1,2], matr[1,0], matr[2,2], matr[2,0])
#crit2, r_max2, q_max2, r_min2, q_min2 = original_trace

def objective_function(params, original_trace):
    rough1, len1, rough2, len2 = params
    crit2, r_max2, q_max2, r_min2, q_min2 = original_trace
    crit1, r_max1, q_max1, r_min1, q_min1 = reflectometry_trace(rough1, len1, rough2, len2)
    return 1e+6*loss_function(crit1, r_max1, q_max1, r_min1, q_min1, crit2, r_max2, q_max2, r_min2, q_min2)

# %%
class Comparator:
    def __init__(self, reference_points):
        self.reference_points = reference_points

    def compare(self, variable_points):
        for ref, var in zip(self.reference_points, variable_points):
            # сравнение
            pass

comparator = Comparator([(0, 0), (1, 1)])
# Вызываем compare много раз без повторной загрузки reference_points

# %%
from scipy.optimize import differential_evolution as de
from scipy.optimize import minimize


# диапазон для шероховатостей и глубин (для двух поверхностных слоёв)
bounds = [[1e-9, 9e-9], [3.e-08, 5.e-08],
          [1e-9, 9e-9], [1.4e-8, 2.6e-8]]

initial_guess = [4e-9, 3.1e-08, 2e-9, 1.5e-8]

# %%
# %%time

# Оптимизация с симплекс-методом
result = minimize(
    objective_function,
    initial_guess,
    method='Nelder-Mead',  
    bounds=bounds
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# File ~\.ai-navigator\micromamba\envs\cuda\Lib\site-packages\scipy\optimize\_minimize.py:726, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     723 callback = _wrap_callback(callback, meth)
#     725 if meth == 'nelder-mead':
# --> 726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
#     729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~\.ai-navigator\micromamba\envs\cuda\Lib\site-packages\scipy\optimize\_optimize.py:833, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     831 try:
# ...

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
# %%time

# Оптимизация с автоматическим численным градиентом вариант 1
result = minimize(
    objective_function,
    initial_guess,
    method='L-BFGS-B',  
    bounds=bounds,
    options={
        'eps': 1e-15, # Шаг для численного градиента
        'maxfun': 1e+8,
        'ftol': 2e-17, 
        'gtol': 1e-20
    }  
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# File ~\.ai-navigator\micromamba\envs\cuda\Lib\site-packages\scipy\optimize\_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# ...

# %%
result

# %%
# %%time

# Оптимизация с автоматическим численным градиентом вариант 2
result = minimize(
    objective_function,
    initial_guess,
    method='TNC',  
    bounds=bounds,
    options={
        'eps': 1e-15, # Шаг для численного градиента
        'maxfun': 1e+8,
        'ftol': 2e-17, 
        'xtol': 1e-20,
        'gtol': 1e-20
            }
)

# %%
result

# %%
import torch
import timeit
import plotly
import matplotlib.pyplot as plt

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
from read_complex_matrix import *
matr = read_complex_matrix('ref_matrix.txt')

# %%
matr = matr.to('cpu')

# %%
from add_roughness import *
from variables import *
fig = plot_density_profile(transform_array(matr, rough_res))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 3
#       1 from add_roughness import *
#       2 from variables import *
# ----> 3 fig = plot_density_profile(transform_array(matr, rough_res))
#       4 fig.show()
#
# File ~\Documents\REF\full_fitting_torch\add_roughness.py:49, in transform_array(input_array, N)
#      46     new_ro = ((torch.erf(erf_input) + 1) / 2) * (ro2 - ro1) + ro1
#      48     # Создаем промежуточные точки
# ---> 49     intermediate_points = torch.stack([new_d_expanded, new_ro], dim=1)
#      50     result_parts.append(intermediate_points)
#      52 # Объединяем все части
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument tensors in method wrapper_CUDA_cat)

# %%
from calculating_dynamic_resolution import *

# %%
q = dynamic_mesh_q(kmax, Ndots, gap)

# %%
r, r_real, r_img = calculate_matrices_and_reflection(matr, rough_res, kmax, q, Ndots, gap)

# %%
from convolution import *

# %%
r_conv = convolution(r, kmax, q, Ndots_norm, sigma1, sigma2, gap)

# %%
from plotting import *
plot_reflection_vs_wavevector_xn([r, r_conv], q, Ndots)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="426ea4e8-5af7-4ce2-9270-4ce32e4a52d2" class="plotly-graph-div" style="height:600px; width:1280px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("426ea4e8-5af7-4ce2-9270-4ce32e4a52d2")) {                    Plotly.newPlot(                        "426ea4e8-5af7-4ce2-9270-4ce32e4a52d2",                        [{"marker":{"color":"#636EFA","opacity":0.92,"size":2.2},"mode":"lines","name":"Dataset 1","x":[0.0029000000000000002,0.0058000000000000005,0.008700000000000001,0.011600000000000001,0.0145,0.017400000000000002,0.020300000000000002,0.023200000000000002,0.0261,0.029,0.0319,0.034800000000000005,0.037700000000000004,0.040600000000000004,0.043500000000000004,0.046400000000000004,0.049300000000000004,0.0522,0.0551,0.05805536363636364,0.06116924223140496,0.0644501379510894,0.06790700898664784,0.07094861638342949,0.07384861638342949,0.07674861638342949,0.07964861638342949,0.08254861638342949,0.08544861638342949,0.08834861638342949,0.09124861638342949,0.09414861638342949,0.09704861638342949,0.09994861638342949,0.10284861638342949,0.10574861638342949,0.10864861638342949,0.11154861638342949,0.11444861638342949,0.11734861638342949,0.12024861638342949,0.12314861638342949,0.12604861638342948,0.12894861638342947,0.13184861638342948,0.1347486163834295,0.13764861638342948,0.1405486163834295,0.14344861638342948,0.1463486163834295],"y":[1.0000000000000018,1.0000000000000004,1.0000000000000004,0.9950959093543363,0.9836519520515876,0.9447456024716228,0.773723322717848,0.23382213355022313,0.005801718885245299,0.055662139646835446,0.050027601503869375,0.02018251388637682,0.0018922149610711954,0.004368748018872315,0.013267179786128746,0.012844108308305593,0.0050214131148147755,0.0005379357066011753,0.0018117844213186084,0.003525188911008885,0.0027332985141417894,0.0009447059993329419,2.5851701007900972e-05,0.00039644591767942306,0.0012697869580442413,0.001515127570631194,0.000798153258046997,0.00011530706816910365,0.00021962191496856928,0.0006205279036477355,0.0006314195169515698,0.00031883770654993947,6.28102086185919e-05,3.9315348834054865e-06,0.00011980873104137876,0.0003000734743894504,0.00033228597098041405,0.00016099220745523733,1.948630747118139e-05,7.742885151483605e-05,0.00019273163501508928,0.0001815649415864191,7.97509292434587e-05,9.590264581005713e-06,4.815138100398621e-06,4.393988114622706e-05,9.333859548411304e-05,9.769869451727968e-05,4.4540670862875116e-05,6.040375976463667e-06],"type":"scatter"},{"marker":{"color":"#EF553B","opacity":0.92,"size":2.2},"mode":"lines","name":"Dataset 2","x":[0.0029000000000000002,0.0058000000000000005,0.008700000000000001,0.011600000000000001,0.0145,0.017400000000000002,0.020300000000000002,0.023200000000000002,0.0261,0.029,0.0319,0.034800000000000005,0.037700000000000004,0.040600000000000004,0.043500000000000004,0.046400000000000004,0.049300000000000004,0.0522,0.0551,0.05805536363636364,0.06116924223140496,0.0644501379510894,0.06790700898664784,0.07094861638342949,0.07384861638342949,0.07674861638342949,0.07964861638342949,0.08254861638342949,0.08544861638342949,0.08834861638342949,0.09124861638342949,0.09414861638342949,0.09704861638342949,0.09994861638342949,0.10284861638342949,0.10574861638342949,0.10864861638342949,0.11154861638342949,0.11444861638342949,0.11734861638342949,0.12024861638342949,0.12314861638342949,0.12604861638342948,0.12894861638342947,0.13184861638342948,0.1347486163834295,0.13764861638342948,0.1405486163834295,0.14344861638342948,0.1463486163834295],"y":[1.0,1.0,0.9981353282928467,0.9907446503639221,0.9688588976860046,0.8797194361686707,0.5684 ...

# %%
from ref import *
from read_complex_matrix import read_complex_matrix
from calculating_dynamic_resolution import *
import pandas as pd
import torch
import torch.optim as optim
torch.set_printoptions(precision=10)

matr = read_complex_matrix('ref_matrix.txt')
import timeit


import warnings

warnings.filterwarnings("ignore", category=UserWarning, message="To copy construct from a tensor")

# %%
q = dynamic_mesh_q(kmax, Ndots, gap)

x_crit, y_max, x_max, y_min, x_min = reflectometry_trace(q, matr)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

#ax.plot(q[0:len(y)]*1e-9, y)
ax.scatter(x_max.detach().numpy()*1e-9, y_max.detach().numpy(), color = 'orange')
ax.scatter(x_min.detach().numpy()*1e-9, y_min.detach().numpy(), color = 'cyan')
ax.scatter(x_crit.detach().numpy()*1e-9, 0.9, color = 'red')

ax.set_yscale('log')

plt.show()

# %%
class Comparator:
    def __init__(self, q, orig_matr):
        self.q = q
        self.original_trace = reflectometry_trace(q, orig_matr)
        
    def compare_trace(self, var_matr):
        crit1, r_max1, q_max1, r_min1, q_min1 = self.original_trace 
        crit2, r_max2, q_max2, r_min2, q_min2 = reflectometry_trace(self.q, var_matr)
        #print(var_matr)
        
        loss = (2*len(r_max1)*(crit1-crit2)/crit1)**2 + torch.sum(((r_max1-r_max2)/r_max1)**2) + torch.sum(((q_max1-q_max2)/q_max1)**2) + torch.sum(((q_min1-q_min2)/q_min1)**2)
        
        return loss

# Вызываем compare много раз без повторной загрузки reference_points
loss_function = Comparator(q, matr)

# %%
all_bounds = torch.tensor([[[1.0000e-09, 1.0000e-09], [0.0000e+00, 0.0000e+00],  [0.0000e+00, 0.0000e+00]],
                           [[1.0000e-08, 9.0000e-08], [8.0000e+14, 8.0000e+14],  [3.0000e-09, 5.0000e-09]],
                           [[1.0000e-08, 3.0000e-08], [-2.0000e+14, -2.0000e+14],[1.0000e-09, 9.0000e-09]],
                           [[1.0000e-09, 1.0000e-09], [2.0000e+14, 2.0000e+14],  [0.0000e+00, 0.0000e+00]]])

# %%
class varbounds:
    def __init__(self, bounds_tensor):
        self.bounds = torch.tensor(bounds_tensor).clone()

    def objective_function(self, var_vector):
        matrixx = self.bounds[..., 0].clone()
        matrixx[torch.where(self.bounds[..., 0] != self.bounds[..., 1])] =  torch.tensor(var_vector*1e-9).clone()
        return loss_function.compare_trace(matrixx)

objective_function = varbounds(all_bounds)

# %%
#в нм
print(objective_function.objective_function(torch.tensor([40, 3, 20, 3])))
# Out:
# tensor(0.0251473441, dtype=torch.float64, grad_fn=<AddBackward0>)

# %%
initial_guess = torch.tensor([40.0, 3.0, 15.0, 2.0]).requires_grad_(True)

# %%
def tryfun(vector):
    a = vector[0]
    b = vector[1]
    c = vector[2]
    d = vector[3]
    return (a-1)**2 + (b-2)**2 + (c-3)**2 + (d-4)**2

# %%
def numerical_gradient(fun, x, eps=1e-4):
    x = x.detach().clone()  # Отключаем автоград и делаем независимую копию
    grad = torch.zeros_like(x)
    
    # Сохраняем исходную форму
    original_shape = x.shape
    x_flat = x.view(-1)
    grad_flat = grad.view(-1)
    
    for i in range(x_flat.numel()):
        # Создаем копии для каждого направления
        x_pos = x_flat.clone()
        x_neg = x_flat.clone()
        
        # Модифицируем конкретный элемент
        x_pos[i] = x_flat[i] + eps
        x_neg[i] = x_flat[i] - eps
        
        # Возвращаем исходную форму для вычисления функции
        f_pos = fun(x_pos.view(original_shape))
        f_neg = fun(x_neg.view(original_shape))
        
        # Вычисляем градиент
        diff = f_pos - f_neg
        grad_flat[i] = diff / (2 * eps)

    return grad.view(original_shape)

# %%
def adamw_useless(fun, x0, lr=3e-11, max_iter=16000, tol=2e-12):
    x = x0.clone().detach().requires_grad_(True)
    optimizer = torch.optim.AdamW([x], lr=lr)
    
    prev_loss = None
    
    for i in range(max_iter):
        optimizer.zero_grad()
        
        loss = fun(x)
        grad = numerical_gradient(fun, x.detach())
        x.grad = grad
        optimizer.step()
        if i%50 == 0: print(loss, "   ",grad,"  ",  x,  "\n")
        
        loss_val = loss.item()
        if prev_loss is not None and abs(prev_loss - loss_val) < tol and i>=600:
            print(f"Converged at iteration {i}, loss: {loss_val}")
            break
        prev_loss = loss_val
    
    return x.detach(), prev_loss

# %%
def numerical_gradient(func, x, epsilon=1e-3):
    grad = torch.zeros_like(x)
    x_flat = x.view(-1)
    grad_flat = grad.view(-1)
    
    for i in range(x_flat.size(0)):
        original = x_flat[i].item()
        
        # Создаем копии для возмущений
        x_plus = x.detach().clone()
        x_plus.view(-1)[i] = original + epsilon
        f_plus = func(x_plus)
        
        x_minus = x.detach().clone()
        x_minus.view(-1)[i] = original - epsilon
        f_minus = func(x_minus)
        
        # Центральная разностная производная
        grad_flat[i] = (f_plus - f_minus) / (2 * epsilon)
    
    return grad

def adamw(func, initial_point, lr=1e-2, max_iter=10000, tol=1e-8, epsilon=1e-6):
    x = torch.nn.Parameter(initial_point.clone().detach(), requires_grad=False)
    optimizer = optim.AdamW([x], lr=lr, weight_decay=0)  # Убрали weight decay
    prev_loss = None
    
    for i in range(max_iter):
        optimizer.zero_grad()
        
        current_loss = func(x)
        grad = numerical_gradient(func, x, epsilon)  # Убедитесь, что функция корректна
        x.grad = grad.clone()
        
        if i % 60 == 0:
            print(f"Iteration {i}: Loss: {current_loss.item():.8f}")
        
        optimizer.step()
        
        # Ранняя остановка при малом изменении потерь
        if prev_loss is not None and abs(prev_loss - current_loss) < tol and i >= 50:
            print(f"Converged at iteration {i}")
            break
            
        prev_loss = current_loss.item()
    
    return x.detach(), current_loss.item()

# %%
ans, loss = adamw(objective_function.objective_function, initial_guess)
print(ans)
print(loss)
# Out:
# Iteration 0: Loss: 0.21029682
# Iteration 60: Loss: 0.16986150
# Iteration 120: Loss: 0.14977533
# Iteration 180: Loss: 0.14780074
# Iteration 240: Loss: 0.14811210
# Iteration 300: Loss: 0.14774846
# Iteration 360: Loss: 0.14735019
# Iteration 420: Loss: 0.14731687
# Iteration 480: Loss: 0.15015023
# Iteration 540: Loss: 0.14723931
# Iteration 600: Loss: 0.14698344
# Iteration 660: Loss: 0.14685789
# Iteration 720: Loss: 0.14654265
# Iteration 780: Loss: 0.14705960
# Iteration 840: Loss: 0.14665172
# Iteration 900: Loss: 0.14610793
# Iteration 960: Loss: 0.14622965
# Iteration 1020: Loss: 0.14942604
# Iteration 1080: Loss: 0.14633790
# Iteration 1140: Loss: 0.14531513
# Iteration 1200: Loss: 0.14765400
# Iteration 1260: Loss: 0.14737724
# Iteration 1320: Loss: 0.14430735
# Iteration 1380: Loss: 0.14484333
# Iteration 1440: Loss: 0.14508775
# Iteration 1500: Loss: 0.14517751
# Iteration 1560: Loss: 0.14547709
# Iteration 1620: Loss: 0.14779610
# Iteration 1680: Loss: 0.14412878
# Iteration 1740: Loss: 0.14454617
# Iteration 1800: Loss: 0.14663010
# Iteration 1860: Loss: 0.14707908
# Iteration 1920: Loss: 0.14401372
# Iteration 1980: Loss: 0.14408331
# Iteration 2040: Loss: 0.14790093
# Iteration 2100: Loss: 0.14400440
# Iteration 2160: Loss: 0.14387891
# Iteration 2220: Loss: 0.14391732
# Iteration 2280: Loss: 0.14732945
# Iteration 2340: Loss: 0.14435895
# Iteration 2400: Loss: 0.14481756
# Iteration 2460: Loss: 0.14503960
# Iteration 2520: Loss: 0.14447233
# Iteration 2580: Loss: 0.14470792
# Iteration 2640: Loss: 0.14476006
# Iteration 2700: Loss: 0.14775640
# Iteration 2760: Loss: 0.14500582
# Iteration 2820: Loss: 0.14462821
# Iteration 2880: Loss: 0.14447024
# Iteration 2940: Loss: 0.14722909
# Iteration 3000: Loss: 0.14458860
# Iteration 3060: Loss: 0.14471927
# Iteration 3120: Loss: 0.14650041
# Iteration 3180: Loss: 0.14367270
# Iteration 3240: Loss: 0.14407092
# Iteration 3300: Loss: 0.14365375
# Converged at iteration 3301
# tensor([40.0000000000,  5.1701989174, 15.5649614334,  2.0347220898])
# 0.1436537504196167

# %%
initial_guess
# Out:
# tensor([40.,  3., 15.,  2.], requires_grad=True)

# %%
#не работает. Сходится абы куда.

def sgd(fun, x0, lr=3e-12, max_iter=16000, tol=2e-12):
    x = x0.clone().detach().requires_grad_(True)
    optimizer = torch.optim.SGD([x], lr=lr)
    
    prev_loss = None
    
    for i in range(max_iter):
        optimizer.zero_grad()
        
        loss = fun(x)
        grad = numerical_gradient(fun, x.detach())
        x.grad = grad
        optimizer.step()
        if i%50 == 0: print(loss, "   ",grad,"  ",  x,  "\n")
        
        loss_val = loss.item()
        if prev_loss is not None and abs(prev_loss - loss_val) < tol and i>=600:
            print(f"Converged at iteration {i}, loss: {loss_val}")
            break
        prev_loss = loss_val
    
    return x.detach(), prev_loss

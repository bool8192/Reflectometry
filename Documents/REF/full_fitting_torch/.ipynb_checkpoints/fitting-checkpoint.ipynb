# %%
from ref import *
from read_complex_matrix import read_complex_matrix
from calculating_dynamic_resolution import *
import pandas as pd
import torch
import torch.optim as optim
torch.set_printoptions(precision=10)

matr = read_complex_matrix('ref_matrix.txt')
import timeit


import warnings

#warnings.filterwarnings("ignore", category=UserWarning, message="To copy construct from a tensor")

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# %%time
q = dynamic_mesh_q(kmax, Ndots, gap)

r, r_conv= reflectometry(q, matr)
# Out:
# CPU times: total: 719 ms
# Wall time: 731 ms

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(q.cpu().detach().numpy()[0:len(r.tolist())]*1e-9, r.tolist())
ax.plot(q.cpu().detach().numpy()[0:len(r_conv.tolist())]*1e-9, r_conv.tolist())

ax.set_yscale('log')

plt.show()

# %%
class Comparator:
    def __init__(self, q, orig_matr):
        self.q = q
        self.orig_matr = orig_matr
        
    def compare_trace(self, var_matr):
        # ВАРИАНТ 1: Вычисляем reference каждый раз (медленно, но правильно)
        r1, r_conv1 = reflectometry(self.q, self.orig_matr)
        r2, r_conv2 = reflectometry(self.q, var_matr)
        
        diff = r1 - r2
        ratio = diff / torch.pow(r1, 0.875)
        squared = diff ** 2
        loss = torch.sum(squared)
    
        return loss


loss_function = Comparator(q, matr)

# %% [markdown]
# <span style="font-size:24px;">Фактически, домножаем квадраты относительного отклонения на веса ниже:</span>

# %%
torch.pow(r, 0.25)
# Out:
# tensor([1.0000000000, 1.0000000000, 1.0000000000, 0.9987717163, 0.9958876912,
#         0.9858905868, 0.9378781582, 0.6953787182, 0.2759873742, 0.4857244688,
#         0.4729360492, 0.3769153295, 0.2085655434, 0.2570924351, 0.3393865830,
#         0.3366479583, 0.2661990211, 0.1522939126, 0.2063130387, 0.2435033719,
#         0.2315452441, 0.1884137647, 0.1168247834, 0.1015918261, 0.1718154238,
#         0.1980195259, 0.1863730762, 0.1369603907, 0.0948661925, 0.1460398958,
#         0.1619542810, 0.1478219768, 0.1123447726, 0.0512076556, 0.0832511402,
#         0.1219502667, 0.1364831058, 0.1264146589, 0.0893432575, 0.0732085370,
#         0.1102467342, 0.1197009337, 0.1066688676, 0.0762093878, 0.0140962712,
#         0.0684001828, 0.0922475928, 0.1010490244, 0.0924717633, 0.0638554290],
#        device='cuda:0', dtype=torch.float64, grad_fn=<PowBackward0>)

# %%
all_bounds = torch.tensor([[[10.00, 10.00], [0.00, 0.00], [0.000, 0.000]],
                           [[100.0, 900.0], [8.00, 8.00], [30.00, 50.00]],
                           [[100.0, 300.0], [-2.0, -2.0], [10.00, 90.00]],
                           [[10.00, 10.00], [2.00, 2.00], [0.000, 0.000]]]).requires_grad_(True)

# %%
class varbounds:
    def __init__(self, bounds_tensor):
        self.bounds = bounds_tensor
        self.mask = self.bounds[..., 0] != self.bounds[..., 1]
        flat_mask = self.mask.flatten()
        self.indices_flat = flat_mask.nonzero().squeeze()
        
    def objective_function(self, var_vector):
        flat_base = self.bounds[..., 0].flatten()
        result = flat_base.scatter(0, self.indices_flat, var_vector)
        target_shape = self.bounds[..., 0].shape
        viewed_result = result.view_as(self.bounds[..., 0])
        final_result = loss_function.compare_trace(viewed_result)
        
        return final_result

objective_function = varbounds(all_bounds)

# %%
objective_function.objective_function(torch.tensor([400.0, 40.0, 200.0, 20.0]))
# Out:
# tensor(3.0365983103e-15, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)

# %%
initial_guess = torch.tensor([360.0001, 30.0001, 240.0001, 18.0001]).requires_grad_(True)

# %%
objective_function.objective_function(initial_guess)
# Out:
# tensor(0.0064242792, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)

# %%
def repair_matrix(bounds, vector):
       mask = bounds[..., 0] != bounds[..., 1]
       flat_mask = mask.flatten()
       indices_flat = flat_mask.nonzero().squeeze()
       flat_base = bounds[..., 0].flatten()
       result = flat_base.scatter(0, indices_flat, vector)
       target_shape = bounds[..., 0].shape
       viewed_result = result.view_as(bounds[..., 0])
       return viewed_result

def twin_plotter(matr, q, r):
    r2, r_conv2 = reflectometry(q, matr)
    fig, ax = plt.subplots(figsize=(15, 2.6))

    ax.plot(q.cpu().detach().numpy()[0:len(r.tolist())]*1e-9, r.tolist())
    ax.plot(q.cpu().detach().numpy()[0:len(r2.tolist())]*1e-9, r2.tolist())

    ax.set_yscale('log')

    plt.show()

# %%
def sgd(fun, x0, lr=9e+4, max_iter=1510, tol=2e-12, k=5):
    k-=1
    x = x0.clone().detach().requires_grad_(True)
    optimizer = torch.optim.SGD([x], lr=lr)
    prev_loss = None
    rel_losses = []
    
    for i in range(max_iter):
        optimizer.zero_grad()
        
        loss = fun(x)
        loss.backward()
        optimizer.step()
        rel_losses.append((loss/objective_function.objective_function(initial_guess)).item())
        if i%int((max_iter-1)/k) == 0: 
                print("relative_loss:  ", (loss/objective_function.objective_function(initial_guess)).item(), "\n", "var_vector:  ", x, "\n", "iteration:  ",  i+1,  "\n")
                twin_plotter(repair_matrix(all_bounds, x), q, r)
        
        loss_val = loss.item()
    
    return x.detach(), loss, rel_losses

# %%
# %%time
ans, loss, rel_losses = sgd(objective_function.objective_function, initial_guess)
# Out:
# relative_loss:   1.0
#  var_vector:   tensor([388.3563537598,  12.4342536926, 234.2076568604,  34.0674171448],
#        requires_grad=True)
#  iteration:   1
# relative_loss:   0.0005522266318276658
#  var_vector:   tensor([387.1102905273,  25.7015552521, 202.2076873779,  28.7535324097],
#        requires_grad=True)
#  iteration:   378
# relative_loss:   0.00020897715306587928
#  var_vector:   tensor([392.2502746582,  30.4931144714, 200.7641601562,  24.1181678772],
#        requires_grad=True)
#  iteration:   755
# relative_loss:   7.628306017600894e-05
#  var_vector:   tensor([395.4784240723,  34.0066452026, 200.1577301025,  21.8425617218],
#        requires_grad=True)
#  iteration:   1132
# relative_loss:   2.6211340619359172e-05
#  var_vector:   tensor([397.4452209473,  36.3183021545, 199.8985290527,  20.6670875549],
#        requires_grad=True)
#  iteration:   1509
# CPU times: total: 2min 25s
# Wall time: 2min 23s

# %%
fig, ax = plt.subplots(figsize =(15, 4))

ax.plot(range(0,len(rel_losses)), rel_losses)

ax.set_yscale('log')

plt.show()

# %%
fig, ax = plt.subplots(figsize =(15, 2.5))

ax.plot(range(0,len(rel_losses[-40:-1])), rel_losses[-40:-1])

ax.set_yscale('log')

plt.show()

# %% [markdown]
# <span style="font-size:24px;">График очень гладкий, не уходит на бешеные числа в начале => Learning rate подобран корректно</span>

# %%
import torch.optim as optim

def adamw(func, initial_point, lr=0.6, max_iter=1510, tol=1e-18, k=5):
    k-=1
    # Создаем полностью изолированный параметр
    x = initial_point.clone().detach().requires_grad_(True)
    
    # Инициализируем оптимизатор
    optimizer = optim.AdamW([x], lr=lr, weight_decay=0, betas=(0.8, 0.99))
    
    # Планировщик для exp уменьшения lr
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.984)
    prev_loss = None
    rel_losses = []
    
    for i in range(max_iter):
        # Полный сброс градиентов
        optimizer.zero_grad(set_to_none=True)
        
        try:
            # Вычисляем функцию потерь с новым графом
            with torch.enable_grad():
                current_loss = func(x)
            
            # Вычисляем градиенты
            current_loss.backward()
            
            # Обновляем параметры
            optimizer.step()
            
            # Обновляем learning rate
            scheduler.step()

            rel_losses.append((current_loss/objective_function.objective_function(initial_guess)).item())
            
            if i%int((max_iter-1)/k) == 0: 
                print("relative_loss:  ", (current_loss/objective_function.objective_function(initial_guess)).item(), "\n","var_vector:  ", x, "\n",  "learning_rate:  ", optimizer.param_groups[0]['lr'],  "\n",  "iteration:  ", i+1,  "\n")
                twin_plotter(repair_matrix(all_bounds, x), q, r)
        
        except RuntimeError as e:
            print(f"Ошибка на итерации {i}: {str(e)}")
            print("Текущее значение x:", x.detach())
            print("Градиент x:", x.grad)
            print("Текущий loss:", current_loss)
            print("Текущий LR:", optimizer.param_groups[0]['lr'])
            raise
        
        # Проверка сходимости
        if prev_loss is not None and abs(prev_loss - current_loss.item()) < tol and i >= 50:
            print(f"Converged at iteration {i}")
            break
            
        prev_loss = current_loss.item()
    
    # Возвращаем результат без графа вычислений
    return x.detach(), current_loss.item(), rel_losses

# %%
# %%time
ans, loss, rel_losses1 = adamw(objective_function.objective_function, initial_guess)
# Out:
# relative_loss:   1.0
#  var_vector:   tensor([360.6000671387,  29.4001293182, 239.4002075195,  18.6000652313],
#        requires_grad=True)
#  learning_rate:   0.6
#  iteration:   1
# relative_loss:   0.0014051228071364022
#  var_vector:   tensor([377.5697631836,  14.4168386459, 203.5547637939,  34.1275939941],
#        requires_grad=True)
#  learning_rate:   0.33034663881637044
#  iteration:   378
# relative_loss:   0.0008074491786571722
#  var_vector:   tensor([382.0971984863,  15.6883811951, 200.6340637207,  26.2117328644],
#        requires_grad=True)
#  learning_rate:   0.1789713989147285
#  iteration:   755
# relative_loss:   0.0002571573394248727
#  var_vector:   tensor([391.3639831543,  23.0603904724, 197.0083770752,  16.2662220001],
#        requires_grad=True)
#  learning_rate:   0.0969610641242207
#  iteration:   1132
# relative_loss:   7.678518354746611e-06
#  var_vector:   tensor([400.4314575195,  35.5027809143, 196.7273254395,  13.2725725174],
#        requires_grad=True)
#  learning_rate:   0.05338460271582476
#  iteration:   1509
# CPU times: total: 2min 21s
# Wall time: 2min 20s

# %%
fig, ax = plt.subplots(figsize =(15, 4))

ax.plot(range(0,len(rel_losses)), rel_losses)
ax.plot(range(0,len(rel_losses1)), rel_losses1)

ax.set_yscale('log')

plt.show()

# %%
fig, ax = plt.subplots(figsize =(15, 2.5))

ax.plot(range(0,len(rel_losses1[-40:-1])), rel_losses1[-40:-1])

ax.set_yscale('log')

plt.show()
